# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
pymac = pd.merge(study_results, mouse_metadata, on="Mouse ID")

# Display the data table for preview
pymac
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
pymac['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_rows = pymac[pymac.duplicated(keep=False)]
print(duplicate_rows)
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0                45.0                 0     Propriva
# 861     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989_data = pymac[pymac['Mouse ID'] == 'g989']
g989_data
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
duplicate_rows = pymac[pymac.duplicated(keep='first')]
print(duplicate_rows)
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 861     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 861  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
pymac = pymac[pymac['Mouse ID'] != 'g989']
pymac
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
pymac['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

drugs = sorted(pymac['Drug Regimen'].unique())
counts = pymac.groupby('Drug Regimen')['Mouse ID'].count()
means = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
medians = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variances = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
stdevs = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sems = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()
drugs
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
data = {
    'Mean Tumor Volume': means,
    'Median Tumor Volume': medians,
    'Tumor Volume Variance': variances,
    'Tumor Volume Std. Dev.': stdevs,
    'Tumor Volume Std. Err.': sems
}

summary_df = pd.DataFrame(data)
summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_df2 = pymac.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(
    Mean=np.mean,
    Median=np.median,
    Variance=np.var,
    Std_Dev=np.std,
    SEM=lambda x: np.std(x, ddof=1) / np.sqrt(len(x))
)
summary_df2
# Out:
#                    Mean     Median   Variance   Std_Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
counts.plot(x='Drug Regimen', y='Mouse ID', kind='bar')
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Observed Mouse Timepoints")
plt.xticks(rotation=45)
plt.title('Total Observations per Drug Regimen')
# Out:
# Text(0.5, 1.0, 'Total Observations per Drug Regimen')

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(drugs, counts, align="center", alpha=0.8)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Observed Mouse Timepoints")
plt.xticks(rotation=45)
plt.title('Total Observations per Drug Regimen')
# Out:
# Text(0.5, 1.0, 'Total Observations per Drug Regimen')

# %%
sex = pymac['Sex'].value_counts()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ['Male', 'Female']
plt.pie(sex, labels=labels, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x16bc97b50>,
# ...
#  [Text(-0.03308201408261547, 1.0995024239828841, 'Male'),
#   Text(0.033082014082615095, -1.0995024239828841, 'Female')],
#  [Text(-0.01804473495415389, 0.5997285948997549, '51.0%'),
#   Text(0.018044734954153686, -0.5997285948997549, '49.0%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
final_tps = pymac.groupby('Mouse ID')['Timepoint'].last()
final_tps

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
# aka - use inner merge to select only the last timepoint rows for each mouse (1880 > 248)
pymac_final = pd.merge(pymac, final_tps, how='inner', on=["Mouse ID", 'Timepoint'])
pymac_final

# filter df for only rows with the 4 drugs of interest (248 > 100)
filtered_df = pymac_final[pymac_final['Drug Regimen'].isin(['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])]
filtered_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128         45           38.982878                 2    Capomulin
# 29      c326          5           36.321346                 0    Infubinol
# 30      c139         45           72.226731                 2    Infubinol
# 31      v339          5           46.250112                 0    Infubinol
# 32      a577         30           57.031862                 2    Infubinol
# ..       ...        ...                 ...               ...          ...
# 243     t565         45           34.455298                 0    Capomulin
# 244     i557         45           47.685963                 1    Capomulin
# 245     m957         45           33.329098                 1    Capomulin
# 246     f966         20           30.485985                 0    Capomulin
# 247     m601         45           28.430964                 1    Capomulin
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# test / thought process step
# goal: find the IQR and outliers of the tumor vol column, for the 4 drugs, grouped by 

capomulin = pymac_final.loc[pymac_final['Drug Regimen'] == 'Capomulin', 'Tumor Volume (mm3)'].tolist()
capomulin
# Out:
# [38.98287774,
#  38.75326548,
#  32.37735684,
#  23.34359787,
#  38.93963263,
#  28.48403281,
#  41.48300765,
#  40.72857787,
#  46.53920617,
#  31.02392294,
#  38.1251644,
#  40.65812366,
#  36.04104736,
#  37.31184577,
#  41.58152074,
#  31.8962384,
#  40.1592203,
#  37.07402422,
#  38.84687569,
#  39.95234669,
#  34.45529799,
#  47.68596303,
#  33.32909778,
#  30.48598484,
#  28.43096411]

# %%
# generate list of tumor volumes for the drugs of interest by creating a dict using loop

# define drugs of interest
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# create empty dict to store the results
results = {}

# loop through each drug
for drug in drugs:
    
    # filter df for only rows with that drug
    filtered_data = pymac_final[pymac_final['Drug Regimen'] == drug]
    
    # output the relevant tumor volumes as a list
    tumor_volume_list = filtered_data['Tumor Volume (mm3)'].tolist()
    
    # store the results in the dictionary
    results[drug] = tumor_volume_list

# print the results for each drug
for drug, values in results.items():
    print(f"Results for {drug}: {values}")
# Out:
# Results for Capomulin: [38.98287774, 38.75326548, 32.37735684, 23.34359787, 38.93963263, 28.48403281, 41.48300765, 40.72857787, 46.53920617, 31.02392294, 38.1251644, 40.65812366, 36.04104736, 37.31184577, 41.58152074, 31.8962384, 40.1592203, 37.07402422, 38.84687569, 39.95234669, 34.45529799, 47.68596303, 33.32909778, 30.48598484, 28.43096411]
# Results for Ramicane: [38.34200823, 36.56165229, 31.56046955, 38.4076183, 43.0475426, 37.31123552, 36.13485243, 44.18345092, 22.05012627, 33.39765251, 37.22565033, 32.97852192, 33.56240217, 29.12847181, 38.81036633, 40.66771292, 30.56462509, 43.16637266, 31.09533505, 30.27623175, 40.65900627, 30.63869575, 43.41938077, 45.22086888, 36.37451039]
# ...

# %%
results['Capomulin']
# Out:
# [38.98287774,
#  38.75326548,
#  32.37735684,
#  23.34359787,
#  38.93963263,
#  28.48403281,
#  41.48300765,
#  40.72857787,
#  46.53920617,
#  31.02392294,
#  38.1251644,
#  40.65812366,
#  36.04104736,
#  37.31184577,
#  41.58152074,
#  31.8962384,
#  40.1592203,
#  37.07402422,
#  38.84687569,
#  39.95234669,
#  34.45529799,
#  47.68596303,
#  33.32909778,
#  30.48598484,
#  28.43096411]

# %%
# determine possible outliers

# copied drug list for visibility 
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# create dict to store outlier results
outlier_results = {}

# loop through each drug of interest
for drug in drugs:
    
    # get the tumor volume values for the current drug from the 'results' dictionary
    tumor_volume_list = results[drug]
    
    # calc the quartiles and iqr for the current drug's tumor volumes
    quartiles = pd.Series(tumor_volume_list).quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq

    # calc the lower and upper bounds for potential outliers
    lower_bound = lowerq - 1.5 * iqr
    upper_bound = upperq + 1.5 * iqr

    # dtm potential outliers for current drug
    potential_outliers = [value for value in tumor_volume_list if (value < lower_bound) or (value > upper_bound)]

    # log results
    outlier_results[drug] = {
        "Lower Quartile": lowerq,
        "Median": quartiles[0.5],
        "Upper Quartile": upperq,
        "IQR": iqr,
        "Lower Bound": lower_bound,
        "Upper Bound": upper_bound,
        "Potential Outliers": potential_outliers
    }

# print the results for each drug
for drug, values in outlier_results.items():
    print(f"Results for {drug}:")
    for key, value in values.items():
        print(f"  {key}: {value}")
# Out:
# Results for Capomulin:
#   Lower Quartile: 32.37735684
#   Median: 38.1251644
#   Upper Quartile: 40.1592203
#   IQR: 7.781863460000004
#   Lower Bound: 20.70456164999999
#   Upper Bound: 51.83201549
#   Potential Outliers: []
# Results for Ramicane:
#   Lower Quartile: 31.56046955
#   Median: 36.56165229
#   Upper Quartile: 40.65900627
#   IQR: 9.098536719999998
#   Lower Bound: 17.912664470000003
#   Upper Bound: 54.30681135
#   Potential Outliers: []
# Results for Infubinol:
#   Lower Quartile: 54.04860769
#   Median: 60.16518046
#   Upper Quartile: 65.52574285
#   IQR: 11.477135160000003
#   Lower Bound: 36.83290494999999
#   Upper Bound: 82.74144559000001
#   Potential Outliers: [36.3213458]
# Results for Ceftamin:
#   Lower Quartile: 48.72207785
#   Median: 59.85195552
#   Upper Quartile: 64.29983003
#   IQR: 15.577752179999997
#   Lower Bound: 25.355449580000002
#   Upper Bound: 87.66645829999999
#   Potential Outliers: []

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
data1 = (results['Capomulin'])
data2 = (results['Ramicane'])
data3 = (results['Infubinol'])
data4 = (results['Ceftamin'])
plt.boxplot([data1, data2, data3, data4], flierprops={'markerfacecolor': 'red', 'marker': 'o', 'markersize': 12})
plt.ylabel("Final Tumor Volume (mm3)")

custom_ticks = [1, 2, 3, 4]
plt.xticks(custom_ticks, drugs)
# Out:
# ([<matplotlib.axis.XTick at 0x16be75f00>,
# ...
#  [Text(1, 0, 'Capomulin'),
#   Text(2, 0, 'Ramicane'),
#   Text(3, 0, 'Infubinol'),
#   Text(4, 0, 'Ceftamin')])

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# use loc to generate x and y value lists
i509tumors = pymac.loc[pymac['Mouse ID'] == 'l509', 'Tumor Volume (mm3)'].tolist()
i509tps = pymac.loc[pymac['Mouse ID'] == 'l509', 'Timepoint'].tolist()

# create and style chart
plt.plot(i509tps, i509tumors)
plt.xlabel("Timepoint (Days)")
plt.ylabel("Final Tumor Volume (mm3)")
plt.title('Capomulin Treatment of Mouse l509')
# Out:
# Text(0.5, 1.0, 'Capomulin Treatment of Mouse l509')

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# use loc to generate x and y value lists
capo = pymac.loc[pymac['Drug Regimen'] == 'Capomulin']
capo_weights = capo.groupby('Mouse ID')['Weight (g)'].mean().tolist()
capo_tumors = capo.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().tolist()

# create and style chart
plt.scatter(capo_weights, capo_tumors)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Capomulin: Mouse Weight vs. Avg. Tumor Volume')
# Out:
# Text(0.5, 1.0, 'Capomulin: Weight vs. Avg. Tumor Volume')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

from scipy.stats import linregress

# copy data creation lines for visibility:
capo = pymac.loc[pymac['Drug Regimen'] == 'Capomulin']
capo_weights = capo.groupby('Mouse ID')['Weight (g)'].mean().tolist()
capo_tumors = capo.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().tolist()

# define x and y values
x_values = capo_weights
y_values = capo_tumors

# create chart
plt.scatter(x_values,y_values, c='blue')
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Capomulin: Mouse Weight vs. Avg. Tumor Volume')

# linear regression calculations
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = np.array(x_values) * slope + intercept

# graph the best fit line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")

print(f"The correlation is: {rvalue}")
# Out:
# The correlation is: 0.8419363424694721
